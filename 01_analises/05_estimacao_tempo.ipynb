# %% [markdown]
# ### Importa código que traz as latitudes e longitudes por bairros

# %%
from geopy.geocoders import Nominatim
import time

# Inicializando o geolocalizador
geolocator = Nominatim(user_agent="meu_aplicativo")

# Lista de bairros ou regiões de São Paulo
bairros = [
    "METALURGICOS,DOS,AV,1797 - CIDADE TIRADENTES",
    "VACANGA,R,300 - CARRAO",
    "ALCANTARA MACHADO,AV,2576 - MOOCA",
    "PASCOAL MOREIRA,R,486 - MOOCA",
    "SOCRATES,GAL,R,145 - PENHA",
    "MANUEL FRANCA DOS SANTOS.AV,174 - SAPOPEMBA",
    "ALVES MALDONADO,R,128 - VILA MATILDE",
    "RODRIGO DE BRUN,AL,1989 - ERMELINO MATARAZZO",
    "ANTONIO LAZARO,R,226 - SAPOPEMBA",
    "SIQUEIRA BUENO,R,1757 - BELEM",
    "CELSO GARCIA,AV,4815 - TATUAPE",
    "OTELO AUGUSTO REIBEIRO, R,899 - GUAIANASES",
    "ANGELO DE CANDIA,R,540 - SAO MATEUS",
    "MARECHAL TITO,AV,6035 - ITAIM PAULISTA",
    "JUVENTUS,R,562 - MOOCA",
    "CELSO GARCIA,AV,2477 - BELEM",
    "HAHNEMANN,R,234 - PARI",
    "SANTA MARCELINA,R,177 - PARQUE DO CARMO",
    "JOSE GUILHERME EIRAS,DR,R,123 - SAO MIGUEL",
    "FRANCISCO FALCONI,R,1501 - VILA PRUDENTE",
    "AUGUSTO CARLOS BAUMANN,R,1074 - ITAQUERA"
]

# Função para buscar SAMU em diferentes bairros de São Paulo
def buscar_samus_em_sao_paulo(bairros):
    resultados = []
    for bairro in bairros:
        print(f"Buscando Hospital em {bairro}...")
        try:
            localizacao = geolocator.geocode(f"{bairro}")
            if localizacao:
                resultados.append({
                    'bairro': bairro,
                    'nome': localizacao.address,
                    'latitude': localizacao.latitude,
                    'longitude': localizacao.longitude
                })
            else:
                print(f"Não encontrado no bairro: {bairro}")
        except Exception as e:
            print(f"Erro ao buscar em {bairro}: {e}")
        
        # Para evitar excesso de requisições, vamos esperar um pouco entre as buscas
        time.sleep(1)
    
    return resultados

# Exemplo de busca
resultados_samu = buscar_samus_em_sao_paulo(bairros)

# Exibir os resultados
if resultados_samu:
    for resultado in resultados_samu:
        print(f"\nBairro: {resultado['bairro']}")
        print(f"Nome: {resultado['nome']}")
        print(f"Localização: {resultado['latitude']}, {resultado['longitude']}")
else:
    print("Nenhuma unidade do SAMU encontrada.")
resultados_samu
# Out:
# Buscando Hospital em METALURGICOS,DOS,AV,1797 - CIDADE TIRADENTES...
# Buscando Hospital em VACANGA,R,300 - CARRAO...
# Buscando Hospital em ALCANTARA MACHADO,AV,2576 - MOOCA...
# Buscando Hospital em PASCOAL MOREIRA,R,486 - MOOCA...
# Buscando Hospital em SOCRATES,GAL,R,145 - PENHA...
# Não encontrado no bairro: SOCRATES,GAL,R,145 - PENHA
# Buscando Hospital em MANUEL FRANCA DOS SANTOS.AV,174 - SAPOPEMBA...
# Não encontrado no bairro: MANUEL FRANCA DOS SANTOS.AV,174 - SAPOPEMBA
# Buscando Hospital em ALVES MALDONADO,R,128 - VILA MATILDE...
# Buscando Hospital em RODRIGO DE BRUN,AL,1989 - ERMELINO MATARAZZO...
# Não encontrado no bairro: RODRIGO DE BRUN,AL,1989 - ERMELINO MATARAZZO
# Buscando Hospital em ANTONIO LAZARO,R,226 - SAPOPEMBA...
# Buscando Hospital em SIQUEIRA BUENO,R,1757 - BELEM...
# Buscando Hospital em CELSO GARCIA,AV,4815 - TATUAPE...
# Buscando Hospital em OTELO AUGUSTO REIBEIRO, R,899 - GUAIANASES...
# Não encontrado no bairro: OTELO AUGUSTO REIBEIRO, R,899 - GUAIANASES
# Buscando Hospital em ANGELO DE CANDIA,R,540 - SAO MATEUS...
# Buscando Hospital em MARECHAL TITO,AV,6035 - ITAIM PAULISTA...
# Buscando Hospital em JUVENTUS,R,562 - MOOCA...
# Buscando Hospital em CELSO GARCIA,AV,2477 - BELEM...
# Buscando Hospital em HAHNEMANN,R,234 - PARI...
# Buscando Hospital em SANTA MARCELINA,R,177 - PARQUE DO CARMO...
# Buscando Hospital em JOSE GUILHERME EIRAS,DR,R,123 - SAO MIGUEL...
# Não encontrado no bairro: JOSE GUILHERME EIRAS,DR,R,123 - SAO MIGUEL
# Buscando Hospital em FRANCISCO FALCONI,R,1501 - VILA PRUDENTE...
# Buscando Hospital em AUGUSTO CARLOS BAUMANN,R,1074 - ITAQUERA...
#
# Bairro: METALURGICOS,DOS,AV,1797 - CIDADE TIRADENTES
# Nome: Avenida Dos Metalúrgicos, 153, Avenida dos Metalúrgicos, Jardim Santa Edwiges, Cidade Tiradentes, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08490-800, Brasil
# Localização: -23.584273, -46.408822
#
# Bairro: VACANGA,R,300 - CARRAO
# Nome: Rua Vacanga, Vila Fernandes, Vila Carrão, Carrão, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03433-025, Brasil
# Localização: -23.5605378, -46.5315852
#
# Bairro: ALCANTARA MACHADO,AV,2576 - MOOCA
# Nome: Avenida Alcântara Machado, 3198, Avenida Alcântara Machado, Mooca, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03163-030, Brasil
# Localização: -23.5446648, -46.5952526
#
# Bairro: PASCOAL MOREIRA,R,486 - MOOCA
# Nome: Rua Pascoal Moreira, 451, 459, Rua Pascoal Moreira, Parque da Mooca, Mooca, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03182-080, Brasil
# Localização: -23.5630291, -46.5908102
#
# Bairro: ALVES MALDONADO,R,128 - VILA MATILDE
# Nome: Hospital Municipal Doutor Alexandre Zaio, 128, Rua Alves Maldonado, Cidade Patriarca, Vila Matilde, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03556-010, Brasil
# Localização: -23.5424, -46.5015296
#
# Bairro: ANTONIO LAZARO,R,226 - SAPOPEMBA
# Nome: 226, Rua Antônio Lázaro, Vila Bancária, Sapopemba, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03921-080, Brasil
# Localização: -23.5875541, -46.5145716
#
# Bairro: SIQUEIRA BUENO,R,1757 - BELEM
# Nome: Rua Siqueira Bueno, Belém, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03059-010, Brasil
# Localização: -23.5431745, -46.5947939
#
# Bairro: CELSO GARCIA,AV,4815 - TATUAPE
# Nome: Hospital Municipal Doutor Cármino Caricchio, 4815, Avenida Celso Garcia, Parque São Jorge, Tatuapé, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03064-000, Brasil
# Localização: -23.5331239, -46.5663866
#
# Bairro: ANGELO DE CANDIA,R,540 - SAO MATEUS
# Nome: Hospital Geral de São Mateus, 540, Rua Ângelo de Cândia, Jardim Imperador, São Mateus, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03958-000, Brasil
# Localização: -23.5947358, -46.4867109
#
# Bairro: MARECHAL TITO,AV,6035 - ITAIM PAULISTA
# Nome: Hospital Santa Marcelina do Itaim Paulista O.S.S, 6035, Avenida Marechal Tito, Vila Itaim, Itaim Paulista, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08115-100, Brasil
# Localização: -23.4924232, -46.3889814
#
# Bairro: JUVENTUS,R,562 - MOOCA
# Nome: 562, Rua Juventus, Parque da Mooca, Mooca, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03124-020, Brasil
# Localização: -23.5718819, -46.5902011
#
# Bairro: CELSO GARCIA,AV,2477 - BELEM
# Nome: Parada 1/2/3 - Fábrica de Cultura Parque Belém, 2043, Avenida Celso Garcia, Vila Operária Maria Zélia, Belém, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03015-000, Brasil
# Localização: -23.5369281, -46.5925601
#
# Bairro: HAHNEMANN,R,234 - PARI
# Nome: Centre médical Hahnemann, Rue Vergniaud, Quartier de la Maison-Blanche, Paris 13e Arrondissement, Paris, Île-de-France, France métropolitaine, 75013, France
# Localização: 48.8300624, 2.3459727
#
# Bairro: SANTA MARCELINA,R,177 - PARQUE DO CARMO
# Nome: HOSPITAL SANTA MARCELINA- ITAQUERA, 177, Rua Santa Marcelina, Parque do Carmo, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08270-070, Brasil
# Localização: -23.5542809, -46.4613548
#
# Bairro: FRANCISCO FALCONI,R,1501 - VILA PRUDENTE
# Nome: Avenida Francisco Falconi, Vila Prudente, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03156-240, Brasil
# Localização: -23.5829286, -46.568661
#
# Bairro: AUGUSTO CARLOS BAUMANN,R,1074 - ITAQUERA
# Nome: Rua Augusto Carlos Bauman, Vila Carmosina, Itaquera, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08210-790, Brasil
# Localização: -23.5351716, -46.4519756
# [{'bairro': 'METALURGICOS,DOS,AV,1797 - CIDADE TIRADENTES',
#   'nome': 'Avenida Dos Metalúrgicos, 153, Avenida dos Metalúrgicos, Jardim Santa Edwiges, Cidade Tiradentes, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08490-800, Brasil',
#   'latitude': -23.584273,
#   'longitude': -46.408822},
#  {'bairro': 'VACANGA,R,300 - CARRAO',
#   'nome': 'Rua Vacanga, Vila Fernandes, Vila Carrão, Carrão, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03433-025, Brasil',
#   'latitude': -23.5605378,
#   'longitude': -46.5315852},
#  {'bairro': 'ALCANTARA MACHADO,AV,2576 - MOOCA',
#   'nome': 'Avenida Alcântara Machado, 3198, Avenida Alcântara Machado, Mooca, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03163-030, Brasil',
#   'latitude': -23.5446648,
#   'longitude': -46.5952526},
#  {'bairro': 'PASCOAL MOREIRA,R,486 - MOOCA',
#   'nome': 'Rua Pascoal Moreira, 451, 459, Rua Pascoal Moreira, Parque da Mooca, Mooca, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03182-080, Brasil',
#   'latitude': -23.5630291,
#   'longitude': -46.5908102},
#  {'bairro': 'ALVES MALDONADO,R,128 - VILA MATILDE',
#   'nome': 'Hospital Municipal Doutor Alexandre Zaio, 128, Rua Alves Maldonado, Cidade Patriarca, Vila Matilde, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03556-010, Brasil',
#   'latitude': -23.5424,
#   'longitude': -46.5015296},
#  {'bairro': 'ANTONIO LAZARO,R,226 - SAPOPEMBA',
#   'nome': '226, Rua Antônio Lázaro, Vila Bancária, Sapopemba, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03921-080, Brasil',
#   'latitude': -23.5875541,
#   'longitude': -46.5145716},
#  {'bairro': 'SIQUEIRA BUENO,R,1757 - BELEM',
#   'nome': 'Rua Siqueira Bueno, Belém, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03059-010, Brasil',
#   'latitude': -23.5431745,
#   'longitude': -46.5947939},
#  {'bairro': 'CELSO GARCIA,AV,4815 - TATUAPE',
#   'nome': 'Hospital Municipal Doutor Cármino Caricchio, 4815, Avenida Celso Garcia, Parque São Jorge, Tatuapé, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03064-000, Brasil',
#   'latitude': -23.5331239,
#   'longitude': -46.5663866},
#  {'bairro': 'ANGELO DE CANDIA,R,540 - SAO MATEUS',
#   'nome': 'Hospital Geral de São Mateus, 540, Rua Ângelo de Cândia, Jardim Imperador, São Mateus, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03958-000, Brasil',
#   'latitude': -23.5947358,
#   'longitude': -46.4867109},
#  {'bairro': 'MARECHAL TITO,AV,6035 - ITAIM PAULISTA',
#   'nome': 'Hospital Santa Marcelina do Itaim Paulista O.S.S, 6035, Avenida Marechal Tito, Vila Itaim, Itaim Paulista, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08115-100, Brasil',
#   'latitude': -23.4924232,
#   'longitude': -46.3889814},
#  {'bairro': 'JUVENTUS,R,562 - MOOCA',
#   'nome': '562, Rua Juventus, Parque da Mooca, Mooca, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03124-020, Brasil',
#   'latitude': -23.5718819,
#   'longitude': -46.5902011},
#  {'bairro': 'CELSO GARCIA,AV,2477 - BELEM',
#   'nome': 'Parada 1/2/3 - Fábrica de Cultura Parque Belém, 2043, Avenida Celso Garcia, Vila Operária Maria Zélia, Belém, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03015-000, Brasil',
#   'latitude': -23.5369281,
#   'longitude': -46.5925601},
#  {'bairro': 'HAHNEMANN,R,234 - PARI',
#   'nome': 'Centre médical Hahnemann, Rue Vergniaud, Quartier de la Maison-Blanche, Paris 13e Arrondissement, Paris, Île-de-France, France métropolitaine, 75013, France',
#   'latitude': 48.8300624,
#   'longitude': 2.3459727},
#  {'bairro': 'SANTA MARCELINA,R,177 - PARQUE DO CARMO',
#   'nome': 'HOSPITAL SANTA MARCELINA- ITAQUERA, 177, Rua Santa Marcelina, Parque do Carmo, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08270-070, Brasil',
#   'latitude': -23.5542809,
#   'longitude': -46.4613548},
#  {'bairro': 'FRANCISCO FALCONI,R,1501 - VILA PRUDENTE',
#   'nome': 'Avenida Francisco Falconi, Vila Prudente, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03156-240, Brasil',
#   'latitude': -23.5829286,
#   'longitude': -46.568661},
#  {'bairro': 'AUGUSTO CARLOS BAUMANN,R,1074 - ITAQUERA',
#   'nome': 'Rua Augusto Carlos Bauman, Vila Carmosina, Itaquera, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08210-790, Brasil',
#   'latitude': -23.5351716,
#   'longitude': -46.4519756}]

# %%
import pandas as pd
df_longitudes = pd.DataFrame(resultados_samu)
df_longitudes['DISTRITO'] = df_longitudes['bairro'].str.split('-').str[1]
df_longitudes

df_longitudes['nome'] = df_longitudes['nome'] + '/' + df_longitudes['latitude'].astype(str) + '/' + df_longitudes['longitude'].astype(str) + '+' + df_longitudes['DISTRITO']
df_longitudes
bairros = df_longitudes['nome'].to_list()
bairros
# Out:
# ['Avenida Dos Metalúrgicos, 153, Avenida dos Metalúrgicos, Jardim Santa Edwiges, Cidade Tiradentes, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08490-800, Brasil/-23.584273/-46.408822+ CIDADE TIRADENTES',
#  'Rua Vacanga, Vila Fernandes, Vila Carrão, Carrão, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03433-025, Brasil/-23.5605378/-46.5315852+ CARRAO',
#  'Avenida Alcântara Machado, 3198, Avenida Alcântara Machado, Mooca, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03163-030, Brasil/-23.5446648/-46.5952526+ MOOCA',
#  'Rua Pascoal Moreira, 451, 459, Rua Pascoal Moreira, Parque da Mooca, Mooca, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03182-080, Brasil/-23.5630291/-46.5908102+ MOOCA',
#  'Hospital Municipal Doutor Alexandre Zaio, 128, Rua Alves Maldonado, Cidade Patriarca, Vila Matilde, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03556-010, Brasil/-23.5424/-46.5015296+ VILA MATILDE',
#  '226, Rua Antônio Lázaro, Vila Bancária, Sapopemba, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03921-080, Brasil/-23.5875541/-46.5145716+ SAPOPEMBA',
#  'Rua Siqueira Bueno, Belém, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03059-010, Brasil/-23.5431745/-46.5947939+ BELEM',
#  'Hospital Municipal Doutor Cármino Caricchio, 4815, Avenida Celso Garcia, Parque São Jorge, Tatuapé, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03064-000, Brasil/-23.5331239/-46.5663866+ TATUAPE',
#  'Hospital Geral de São Mateus, 540, Rua Ângelo de Cândia, Jardim Imperador, São Mateus, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03958-000, Brasil/-23.5947358/-46.4867109+ SAO MATEUS',
#  'Hospital Santa Marcelina do Itaim Paulista O.S.S, 6035, Avenida Marechal Tito, Vila Itaim, Itaim Paulista, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08115-100, Brasil/-23.4924232/-46.3889814+ ITAIM PAULISTA',
#  '562, Rua Juventus, Parque da Mooca, Mooca, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03124-020, Brasil/-23.5718819/-46.5902011+ MOOCA',
#  'Parada 1/2/3 - Fábrica de Cultura Parque Belém, 2043, Avenida Celso Garcia, Vila Operária Maria Zélia, Belém, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03015-000, Brasil/-23.5369281/-46.5925601+ BELEM',
#  'Centre médical Hahnemann, Rue Vergniaud, Quartier de la Maison-Blanche, Paris 13e Arrondissement, Paris, Île-de-France, France métropolitaine, 75013, France/48.8300624/2.3459727+ PARI',
#  'HOSPITAL SANTA MARCELINA- ITAQUERA, 177, Rua Santa Marcelina, Parque do Carmo, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08270-070, Brasil/-23.5542809/-46.4613548+ PARQUE DO CARMO',
#  'Avenida Francisco Falconi, Vila Prudente, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 03156-240, Brasil/-23.5829286/-46.568661+ VILA PRUDENTE',
#  'Rua Augusto Carlos Bauman, Vila Carmosina, Itaquera, São Paulo, Região Imediata de São Paulo, Região Metropolitana de São Paulo, São Paulo, Região Sudeste, 08210-790, Brasil/-23.5351716/-46.4519756+ ITAQUERA']

# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd
import requests
import time
from shapely.geometry import box

# --- 1. Baixar o polígono da Cidade Tiradentes ---
bairro = ox.geocode_to_gdf("Cidade Tiradentes, São Paulo, Brasil")

# --- 2. Criar a grade (grid) sobre o bairro ---



def criar_grid(bairro, tamanho=0.002):  # Aproximadamente 200m
    minx, miny, maxx, maxy = bairro.total_bounds
    grid = []
    x = minx
    while x < maxx:
        y = miny
        while y < maxy:
            grid.append(box(x, y, x + tamanho, y + tamanho))
            y += tamanho
        x += tamanho
    grid_gdf = gpd.GeoDataFrame(geometry=grid, crs=bairro.crs)
    grid_gdf = gpd.overlay(grid_gdf, bairro, how='intersection')
    return grid_gdf

grid = criar_grid(bairro)

# --- 3. Corrigir projeção para metros, calcular centroide ---
grid = grid.to_crs(epsg=3857)  # Web Mercator
grid["centroide"] = grid.geometry.centroid

# --- 4. Criar colunas separadas de latitude/longitude
centroides = grid["centroide"].to_crs(epsg=4326)  # voltar para lat/lon
grid["centroide_lon"] = centroides.geometry.x
grid["centroide_lat"] = centroides.geometry.y

# --- 5. Estimar população ---
populacao_total = 211501
populacao_por_grid = populacao_total / len(grid)
grid["populacao_estimada"] = populacao_por_grid

# --- 6. Definir hospital e API ---
API_KEY = "5b3ce3597851110001cf624824d680a2a89c4dc48933794aaca7b81d"
hospital_coords = [-46.4165, -23.5698]  # (longitude, latitude)

def calcular_tempo(origem, destino, api_key):
    url = "https://api.openrouteservice.org/v2/directions/driving-car/json"
    headers = {
        "Authorization": api_key,
        "Content-Type": "application/json"
    }
    body = {
        "coordinates": [origem, destino]
    }
    try:
        response = requests.post(url, json=body, headers=headers)
        if response.status_code == 200:
            dados = response.json()
            tempo_segundos = dados['routes'][0]['summary']['duration']
            tempo_minutos = tempo_segundos / 60
            return tempo_minutos
        else:
            print("Erro na API:", response.text)
            return None
    except Exception as e:
        print(f"Erro: {e}")
        return None

# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd
import requests
import time
from shapely.geometry import box

df_final = pd.DataFrame()

lista = bairros
for i in lista: 
    # --- 1. Baixar o polígono da Cidade Tiradentes ---
    loc = i.split('+')[1]
    bairro = ox.geocode_to_gdf(f"{loc}, São Paulo, Brasil")

    # --- 2. Criar a grade (grid) sobre o bairro ---
    def criar_grid(bairro, tamanho=0.002):  # Aproximadamente 200m
        minx, miny, maxx, maxy = bairro.total_bounds
        grid = []
        x = minx
        while x < maxx:
            y = miny
            while y < maxy:
                grid.append(box(x, y, x + tamanho, y + tamanho))
                y += tamanho
            x += tamanho
        grid_gdf = gpd.GeoDataFrame(geometry=grid, crs=bairro.crs)
        grid_gdf = gpd.overlay(grid_gdf, bairro, how='intersection')
        return grid_gdf

    grid = criar_grid(bairro)



    # --- 3. Corrigir projeção para metros, calcular centroide ---
    grid = grid.to_crs(epsg=3857)  # Web Mercator
    grid["centroide"] = grid.geometry.centroid

    # --- 4. Criar colunas separadas de latitude/longitude
    centroides = grid["centroide"].to_crs(epsg=4326)  # voltar para lat/lon
    grid["centroide_lon"] = centroides.geometry.x
    grid["centroide_lat"] = centroides.geometry.y

    # --- 5. Estimar população ---
    populacao_total = 211501
    populacao_por_grid = populacao_total / len(grid)
    grid["populacao_estimada"] = populacao_por_grid

    # --- 6. Definir hospital e API ---
    API_KEY = "5b3ce3597851110001cf624824d680a2a89c4dc48933794aaca7b81d"


    long = i.split('/')[1]
    lati = i.split('/')[2]
    grid["latitude_hospital"] = lati
    grid["longitude_hospital"] = long



    hospital_coords = [long, lati]  # (longitude, latitude)
    # display(grid)
    # df_final

    # hospital_coords = [grid["longitude_hospital"].iloc[0], grid["latitude_hospital"].iloc[0]]
    # hospital_coords

        
    long = float(i.split('/')[1])
    lati = float(i.split('/')[2].split('+')[0])

    grid["latitude_hospital"] = lati
    grid["longitude_hospital"] = long

    hospital_coords = [lati, long]



    print(hospital_coords)

    def calcular_tempo(origem, destino, api_key):
        url = "https://api.openrouteservice.org/v2/directions/driving-car/json"
        headers = {
            "Authorization": api_key,
            "Content-Type": "application/json"
        }
        body = {
            "coordinates": [origem, destino]
        }
        try:
            response = requests.post(url, json=body, headers=headers)
            if response.status_code == 200:
                dados = response.json()
                tempo_segundos = dados['routes'][0]['summary']['duration']
                tempo_minutos = tempo_segundos / 60
                return tempo_minutos
            else:
                print(f"⚠️ Erro na API para o ponto {origem}: {response.text}")
                return -1  # Marca -1 para indicar que não deu
        except Exception as e:
            print(f"❌ Erro de conexão: {e}")
            return -1


    # --- 7. Rodar para todos os centroides ---
    tempos = []
    for idx, row in grid.iterrows():
        origem = [row["centroide_lon"], row["centroide_lat"]]
        # Chamada da função
        tempo = calcular_tempo(origem, hospital_coords, API_KEY)
        tempos.append(tempo)
        time.sleep(1)  # pra não travar a API

    grid["tempo_minutos"] = tempos

    # --- 8. Salvar o resultado de forma segura ---

    # 1. Garante que está em WGS84 (lat/lon)
    if grid.crs.to_epsg() != 4326:
        grid = grid.to_crs(epsg=4326)

    # 2. Corrigir geometrias inválidas se necessário
    grid["geometry"] = grid["geometry"].buffer(0)

    # 3. Salvar o GeoJSON
    try:
        grid.to_file("grids_cidade_tiradentes.geojson", driver="GeoJSON")
        print("✅ Arquivo GeoJSON salvo com sucesso!")
    except Exception as e:
        print(f"❌ Erro ao salvar GeoJSON: {e}")

    # 4. Salvar o CSV
    try:
        grid[["centroide_lon", "centroide_lat", "populacao_estimada", "tempo_minutos"]].to_csv(f"estimativa_deslocamento {loc}.csv", index=False)
        print("✅ Arquivo CSV salvo com sucesso!")
    except Exception as e:
        print(f"❌ Erro ao salvar CSV: {e}")

    print("🏁 Processo finalizado.")

    df_final = pd.concat([df_final, grid])
# Out:
# [-46.408822, -23.584273]
# ❌ Erro ao salvar GeoJSON: GeoDataFrame contains multiple geometry columns but GeoDataFrame.to_file supports only a single geometry column. Use a GeoDataFrame.to_parquet or GeoDataFrame.to_feather, drop additional geometry columns or convert them to a supported format like a well-known text (WKT) using `GeoSeries.to_wkt()`.
# ✅ Arquivo CSV salvo com sucesso!
# 🏁 Processo finalizado.
# [-46.5315852, -23.5605378]
# ❌ Erro ao salvar GeoJSON: GeoDataFrame contains multiple geometry columns but GeoDataFrame.to_file supports only a single geometry column. Use a GeoDataFrame.to_parquet or GeoDataFrame.to_feather, drop additional geometry columns or convert them to a supported format like a well-known text (WKT) using `GeoSeries.to_wkt()`.
# ✅ Arquivo CSV salvo com sucesso!
# 🏁 Processo finalizado.
# [-46.5952526, -23.5446648]
# ❌ Erro de conexão: HTTPSConnectionPool(host='api.openrouteservice.org', port=443): Max retries exceeded with url: /v2/directions/driving-car/json (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000025F2CC69190>, 'Connection to api.openrouteservice.org timed out. (connect timeout=None)'))
# ❌ Erro ao salvar GeoJSON: GeoDataFrame contains multiple geometry columns but GeoDataFrame.to_file supports only a single geometry column. Use a GeoDataFrame.to_parquet or GeoDataFrame.to_feather, drop additional geometry columns or convert them to a supported format like a well-known text (WKT) using `GeoSeries.to_wkt()`.
# ✅ Arquivo CSV salvo com sucesso!
# 🏁 Processo finalizado.
# [-46.5908102, -23.5630291]
# ❌ Erro ao salvar GeoJSON: GeoDataFrame contains multiple geometry columns but GeoDataFrame.to_file supports only a single geometry column. Use a GeoDataFrame.to_parquet or GeoDataFrame.to_feather, drop additional geometry columns or convert them to a supported format like a well-known text (WKT) using `GeoSeries.to_wkt()`.
# ✅ Arquivo CSV salvo com sucesso!
# 🏁 Processo finalizado.
# [-46.5015296, -23.5424]
# ❌ Erro ao salvar GeoJSON: GeoDataFrame contains multiple geometry columns but GeoDataFrame.to_file supports only a single geometry column. Use a GeoDataFrame.to_parquet or GeoDataFrame.to_feather, drop additional geometry columns or convert them to a supported format like a well-known text (WKT) using `GeoSeries.to_wkt()`.
# ✅ Arquivo CSV salvo com sucesso!
# 🏁 Processo finalizado.
# [-46.5145716, -23.5875541]
# ⚠️ Erro na API para o ponto [-46.50333700794088, -23.596792617013822]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50359876295731, -23.5953277741813]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50164156273371, -23.62425292881791]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.622784303816715]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.62078430381635]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.618784303815985]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.616784303815624]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.614784303815263]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.6127843038149]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.61078430381454]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.608784303814183]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.606784303813818]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.604784303813457]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.602784303813102]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.60078430381273]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.50132799999995, -23.59878430381237]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.501416117052706, -23.59713362433001]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.498759489579435, -23.62392197605854]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49932871967782, -23.622782048218507]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.499327999999956, -23.62078430381635]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49932799999994, -23.618784303815985]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.499327999999956, -23.616784303815624]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49932799999994, -23.614784303815263]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49932799999994, -23.6127843038149]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.499383962128974, -23.610939341626263]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.499372664378036, -23.60873051262964]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49932799999994, -23.606784303813818]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.499327999999956, -23.604784303813457]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49932799999994, -23.602784303813102]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49932799999994, -23.60078430381273]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49932799999994, -23.59878430381237]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49937518171969, -23.59724199878836]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497320696916155, -23.62425875925255]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497327999999946, -23.622784303816715]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49732799999994, -23.62078430381635]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497327999999946, -23.618784303815985]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49732799999995, -23.61678430381562]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497327999999946, -23.614784303815266]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497327999999946, -23.6127843038149]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49729770829575, -23.610823335276045]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497694297840965, -23.608544658738463]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497665669594284, -23.606725174553272]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497436612273596, -23.604753106169948]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497530732660955, -23.602784471435204]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49736647676998, -23.600758313359965]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.497327999999946, -23.598784303812373]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49718963681042, -23.596957360074967]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.496568612526126, -23.595636667729437]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.4951938476162, -23.62421221592907]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49532799999994, -23.622784303816715]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49532799999994, -23.62078430381635]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49532799999996, -23.618784303815985]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.495327999999944, -23.61678430381562]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.495327999999944, -23.614784303815266]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49532799999994, -23.6127843038149]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.495327999999944, -23.610784303814544]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49516545590701, -23.60936741638511]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49626076935795, -23.600063384096853]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49611267028639, -23.598545865330465]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49583736980777, -23.59670827013377]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.4957831550946, -23.595582354329352]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.493469208946266, -23.62447606709691]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49332799999995, -23.622784303816715]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49332799999994, -23.62078430381635]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49332799999995, -23.618784303815985]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.493327999999956, -23.616784303815624]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49332799999995, -23.614784303815263]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49332799999994, -23.6127843038149]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49332799999995, -23.61078430381454]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49325878490135, -23.609030709569904]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.491216066639424, -23.62414439286802]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49132799999994, -23.622784303816715]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49132799999994, -23.62078430381635]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.491327999999946, -23.618784303815985]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49132799999994, -23.61678430381562]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49132799999994, -23.614784303815266]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.491327999999946, -23.6127843038149]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49132799999994, -23.610784303814544]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.491310458778045, -23.608807571419753]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.49068897311148, -23.60770239796996]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48964185398036, -23.624115997313886]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48932799999994, -23.622784303816715]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48932799999993, -23.62078430381635]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48932799999995, -23.618784303815985]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48932799999994, -23.616784303815624]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48932799999994, -23.614784303815263]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48932799999994, -23.6127843038149]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48932799999994, -23.61078430381454]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48932799999994, -23.608784303814183]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48916796842048, -23.60752984600507]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48807985912131, -23.623906727414134]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48745720201721, -23.62263265963899]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48732799999994, -23.62078430381635]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48732799999994, -23.618784303815985]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48732799999993, -23.616784303815624]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48732799999994, -23.614784303815263]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48732799999993, -23.6127843038149]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48732799999994, -23.61078430381454]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48732799999994, -23.608784303814183]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48726142967085, -23.60732429087112]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.484349586854414, -23.623795466971206]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48523264346005, -23.622479864708534]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48532799999994, -23.62078430381635]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48532799999993, -23.618784303815985]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48532952498553, -23.616785817685944]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48555937365813, -23.61484808007717]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.485829922860155, -23.61287396419389]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48564598865876, -23.610506711613933]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48547450060704, -23.60886201088262]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48593700827897, -23.60740497157103]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48408777323553, -23.623840781770003]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48399447020599, -23.622686523066776]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.483858973301174, -23.62081252765116]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48395156172954, -23.61885711493367]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.4840333664892, -23.617090836142044]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.48429133333329, -23.610267858417632]: {
#     "error": "Quota exceeded"
# }
# ❌ Erro ao salvar GeoJSON: GeoDataFrame contains multiple geometry columns but GeoDataFrame.to_file supports only a single geometry column. Use a GeoDataFrame.to_parquet or GeoDataFrame.to_feather, drop additional geometry columns or convert them to a supported format like a well-known text (WKT) using `GeoSeries.to_wkt()`.
# ✅ Arquivo CSV salvo com sucesso!
# 🏁 Processo finalizado.
# [-46.5947939, -23.5431745]
# ⚠️ Erro na API para o ponto [-46.611054510670186, -23.53446579164912]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.61128615763973, -23.533219874769983]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.6106735524892, -23.531891949804418]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60894513778713, -23.536393534179606]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60949261184769, -23.534967096607627]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.609543999999985, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.609321625841915, -23.531248558723064]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60866065174478, -23.529907803841652]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60680140540137, -23.542429340049672]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.607025289202404, -23.540921725928555]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.607302126595286, -23.53895667227928]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.607526304635954, -23.537006488436933]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.607544, -23.5350210038008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.607544, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.607544, -23.53102100380008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.607308446618134, -23.52926156853937]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.6066479071652, -23.52791575845182]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60662973350218, -23.52435178693343]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60674428160223, -23.523418091507875]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60493806672226, -23.54458651529871]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60545798857726, -23.54294059650204]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60554399999998, -23.54102100380189]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60554399999999, -23.539021003801526]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60554399999999, -23.53702100380117]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60554399999999, -23.5350210038008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60554399999999, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.605543999999995, -23.53102100380008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60554399999999, -23.52902100379972]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60538498899341, -23.527061989229555]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60551294735187, -23.524998414700512]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.605522773254215, -23.523393127357952]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60358249453719, -23.544847180260987]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.603544, -23.543021003802256]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.603543999999985, -23.54102100380189]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60354399999999, -23.539021003801526]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60354399999999, -23.53702100380117]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.603543999999985, -23.5350210038008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60354399999999, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60354399999999, -23.53102100380008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60354399999999, -23.52902100379972]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60354399999999, -23.52702100379936]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.603543999999985, -23.525021003799]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60362913997271, -23.523479054675647]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60159747549418, -23.54465032391988]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.601543999999976, -23.54302100380225]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.601543999999976, -23.541021003801887]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60154399999998, -23.539021003801526]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.601543999999976, -23.53702100380117]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60154399999998, -23.5350210038008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.601543999999976, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60154399999998, -23.53102100380008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60154399999998, -23.52902100379972]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60154399999998, -23.52702100379936]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.601602507546176, -23.52508408087928]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.602152959731676, -23.523771508235495]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59962263513754, -23.5444527642982]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59954399999998, -23.543021003802256]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59954399999998, -23.54102100380189]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.599543999999966, -23.539021003801526]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59954399999998, -23.53702100380117]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59954399999998, -23.5350210038008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59954399999998, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59954399999998, -23.53102100380008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59954399999998, -23.52902100379972]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59955661988604, -23.52703396285055]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.60000140615991, -23.5255874797248]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.597692876189214, -23.5442597879101]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59754399999998, -23.543021003802256]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59754399999998, -23.54102100380189]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59754399999998, -23.539021003801526]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59754399999997, -23.53702100380117]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59754399999998, -23.5350210038008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59754399999998, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59754399999997, -23.53102100380008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59754399999998, -23.52902100379972]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59784889387872, -23.52745517127547]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.596130999999986, -23.544103600051887]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59555496425036, -23.543007058298823]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59554399999998, -23.541021003801887]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59554399999998, -23.539021003801526]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59554399999997, -23.53702100380117]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59554399999998, -23.5350210038008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59554399999998, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59554399999998, -23.53102100380008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59571898055725, -23.52928822834524]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59650594635625, -23.527991832434715]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.592887332143846, -23.544472942779333]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.5935149363629, -23.54296363982814]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.593543999999966, -23.54102100380189]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59354399999998, -23.539021003801526]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59354399999998, -23.53702100380117]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59354399999998, -23.5350210038008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59354399999998, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59354399999998, -23.53102100380008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59371759906938, -23.529785407560297]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59105286632614, -23.546581511665725]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.591509101598426, -23.54498996577851]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59154399999998, -23.54302100380224]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59154399999997, -23.541021003801887]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59154399999997, -23.539021003801526]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59154399999998, -23.53702100380117]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.591543999999985, -23.5350210038008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.591543999999985, -23.533021003800442]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.59154399999998, -23.53102100380008]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.591513581773334, -23.52990291654104]: {
#     "error": "Quota exceeded"
# }
# ⚠️ Erro na API para o ponto [-46.58911043834104, -23.54863366451112]: {
#     "error": "Quota exceeded"
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 111
#     109     tempo = calcular_tempo(origem, hospital_coords, API_KEY)
#     110     tempos.append(tempo)
# --> 111     time.sleep(1)  # pra não travar a API
#     113 grid["tempo_minutos"] = tempos
#     115 # --- 8. Salvar o resultado de forma segura ---
#     116
#     117 # 1. Garante que está em WGS84 (lat/lon)
#
# KeyboardInterrupt:

# %%
import requests
import time

def calcular_tempo(origem, destino, api_key):
    url = "https://api.openrouteservice.org/v2/directions/driving-car/json"
    headers = {
        "Authorization": api_key,
        "Content-Type": "application/json"
    }
    body = {
        "coordinates": [origem, destino]
    }
    try:
        response = requests.post(url, json=body, headers=headers)
        if response.status_code == 200:
            dados = response.json()
            tempo_segundos = dados['routes'][0]['summary']['duration']
            tempo_minutos = tempo_segundos / 60
            return tempo_minutos
        else:
            print("Erro na API:", response.text)
            return None
    except Exception as e:
        print(f"Erro: {e}")
        return None

# Ajuste nas coordenadas do hospital e pontos próximos
hospital_coords = [-46.408822, -23.584273]  # Garantir que esteja na ordem correta [lon, lat]
# Tentar com um ponto aleatório para validar a resposta
origem = [-46.42176074613922, -23.574410545070076]  # Exemplo de coordenada próxima

tempo = calcular_tempo(origem, hospital_coords, "5b3ce3597851110001cf624824d680a2a89c4dc48933794aaca7b81d")
print(f"Tempo de deslocamento: {tempo} minutos")
# Out:
# Tempo de deslocamento: 8.06 minutos

# %%
hospital_coords = [grid["longitude_hospital"].iloc[0], grid["latitude_hospital"].iloc[0]]
hospital_coords

# Exemplo do seu dado
dado = ['-23.5351716', '-46.4519756+ ITAQUERA']

# Tirar o que vem depois do "+"
limpo = [x.split('+')[0] for x in dado]

# Transformar em número float
hospital_coords = [float(x) for x in limpo]

print(hospital_coords)
# Out:
# [-23.5351716, -46.4519756]

# %%
df_final
# Out:
#      bbox_west  bbox_south  bbox_east  bbox_north  place_id  osm_type  \
# 0   -46.423470  -23.616132 -46.377023  -23.562142   8037361  relation
# 1   -46.423470  -23.616132 -46.377023  -23.562142   8037361  relation
# 2   -46.423470  -23.616132 -46.377023  -23.562142   8037361  relation
# 3   -46.423470  -23.616132 -46.377023  -23.562142   8037361  relation
# 4   -46.423470  -23.616132 -46.377023  -23.562142   8037361  relation
# ..         ...         ...        ...         ...       ...       ...
# 370 -46.477552  -23.556978 -46.429414  -23.513474   8054392  relation
# 371 -46.477552  -23.556978 -46.429414  -23.513474   8054392  relation
# 372 -46.477552  -23.556978 -46.429414  -23.513474   8054392  relation
# 373 -46.477552  -23.556978 -46.429414  -23.513474   8054392  relation
# 374 -46.477552  -23.556978 -46.429414  -23.513474   8054392  relation
#
#       osm_id        lat        lon     class  ... place_rank  importance  \
# 0    3049440 -23.582497 -46.409207  boundary  ...         18    0.395415
# 1    3049440 -23.582497 -46.409207  boundary  ...         18    0.395415
# 2    3049440 -23.582497 -46.409207  boundary  ...         18    0.395415
# 3    3049440 -23.582497 -46.409207  boundary  ...         18    0.395415
# 4    3049440 -23.582497 -46.409207  boundary  ...         18    0.395415
# ..       ...        ...        ...       ...  ...        ...         ...
# 370  3049502 -23.536080 -46.455510  boundary  ...         18    0.402573
# 371  3049502 -23.536080 -46.455510  boundary  ...         18    0.402573
# 372  3049502 -23.536080 -46.455510  boundary  ...         18    0.402573
# 373  3049502 -23.536080 -46.455510  boundary  ...         18    0.402573
# 374  3049502 -23.536080 -46.455510  boundary  ...         18    0.402573
#
#      addresstype               name  \
# 0         suburb  Cidade Tiradentes
# 1         suburb  Cidade Tiradentes
# 2         suburb  Cidade Tiradentes
# 3         suburb  Cidade Tiradentes
# 4         suburb  Cidade Tiradentes
# ..           ...                ...
# 370       suburb           Itaquera
# 371       suburb           Itaquera
# 372       suburb           Itaquera
# 373       suburb           Itaquera
# 374       suburb           Itaquera
#
#                                           display_name  \
# 0    Cidade Tiradentes, São Paulo, Região Imediata ...
# 1    Cidade Tiradentes, São Paulo, Região Imediata ...
# 2    Cidade Tiradentes, São Paulo, Região Imediata ...
# 3    Cidade Tiradentes, São Paulo, Região Imediata ...
# 4    Cidade Tiradentes, São Paulo, Região Imediata ...
# ..                                                 ...
# 370  Itaquera, São Paulo, Região Imediata de São Pa...
# 371  Itaquera, São Paulo, Região Imediata de São Pa...
# 372  Itaquera, São Paulo, Região Imediata de São Pa...
# 373  Itaquera, São Paulo, Região Imediata de São Pa...
# 374  Itaquera, São Paulo, Região Imediata de São Pa...
#
#                                               geometry  \
# 0    POLYGON ((-5167614.402 -2701599.49, -5167614.4...
# 1    POLYGON ((-5167614.402 -2701356.58, -5167614.4...
# 2    POLYGON ((-5167614.402 -2701113.674, -5167614....
# 3    POLYGON ((-5167614.402 -2700870.771, -5167614....
# 4    POLYGON ((-5167614.402 -2700870.771, -5167644....
# ..                                                 ...
# 370  POLYGON ((-5168514.086 -2696601.833, -5168736....
# 371  POLYGON ((-5168736.725 -2696358.999, -5168736....
# 372  POLYGON ((-5168736.725 -2696116.169, -5168736....
# 373  POLYGON ((-5168514.086 -2696601.833, -5168513....
# 374  POLYGON ((-5168514.086 -2696601.833, -5168514....
#
#                              centroide centroide_lon  centroide_lat  \
# 0    POINT (-5167646.768 -2701633.272)    -46.421761     -23.574411
# 1    POINT (-5167705.765 -2701460.421)    -46.422291     -23.572987
# 2    POINT (-5167698.449 -2701257.938)    -46.422225     -23.571320
# 3    POINT (-5167634.688 -2701008.288)    -46.421652     -23.569265
# 4    POINT (-5167625.022 -2700821.669)    -46.421565     -23.567728
# ..                                 ...           ...            ...
# 370  POINT (-5168640.677 -2696487.343)    -46.430689     -23.532035
# 371  POINT (-5168678.826 -2696257.309)    -46.431032     -23.530140
# 372  POINT (-5168718.925 -2696076.063)    -46.431392     -23.528648
# 373  POINT (-5168508.958 -2696642.086)    -46.429506     -23.533310
# 374   POINT (-5168514.048 -2696601.69)    -46.429552     -23.532977
#
#      populacao_estimada
# 0            542.310256
# 1            542.310256
# 2            542.310256
# 3            542.310256
# 4            542.310256
# ..                  ...
# 370          564.002667
# 371          564.002667
# 372          564.002667
# 373          564.002667
# 374          564.002667
#
# [3900 rows x 21 columns]
