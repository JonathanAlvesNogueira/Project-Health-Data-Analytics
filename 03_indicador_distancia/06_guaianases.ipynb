# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd
import requests
import time
from shapely.geometry import box

# --- 1. Baixar o polígono do arthur alvim ---
bairro = ox.geocode_to_gdf("Guaianases, São Paulo")

# --- 2. Criar a grade (grid) sobre o bairro ---
def criar_grid(bairro, tamanho=0.005):  # Aproximadamente 200m
    minx, miny, maxx, maxy = bairro.total_bounds
    grid = []
    x = minx
    while x < maxx:
        y = miny
        while y < maxy:
            grid.append(box(x, y, x + tamanho, y + tamanho))
            y += tamanho
        x += tamanho
    grid_gdf = gpd.GeoDataFrame(geometry=grid, crs=bairro.crs)
    grid_gdf = gpd.overlay(grid_gdf, bairro, how='intersection')
    return grid_gdf

grid = criar_grid(bairro)


# --- 3. Corrigir projeção para metros, calcular centroide ---
grid = grid.to_crs(epsg=3857)  # Web Mercator
grid["centroide"] = grid.geometry.centroid

# --- 4. Criar colunas separadas de latitude/longitude
centroides = grid["centroide"].to_crs(epsg=4326)  # voltar para lat/lon
grid["centroide_lon"] = centroides.geometry.x
grid["centroide_lat"] = centroides.geometry.y

# --- 6. Definir hospital e API ---
API_KEY = "5b3ce3597851110001cf624824d680a2a89c4dc48933794aaca7b81d"  # Troque aqui pela sua chave
hospital_coords = [-46.4064284, -23.5521168]

def calcular_distancia_km(origem, destino, api_key):
    url = "https://api.openrouteservice.org/v2/directions/driving-car/json"
    headers = {
        "Authorization": api_key,
        "Content-Type": "application/json"
    }
    body = {
        "coordinates": [origem, destino]
    }
    try:
        response = requests.post(url, json=body, headers=headers)
        if response.status_code == 200:
            dados = response.json()
            distancia_metros = dados['routes'][0]['summary']['distance']
            distancia_km = distancia_metros / 1000
            return round(distancia_km, 2)
        else:
            print("Erro na API:", response.text)
            return None
    except Exception as e:
        print(f"Erro: {e}")
        return None

# --- 7. Calcular a distância para cada grid ---
distancias_km = []
for i, row in grid.iterrows():
    origem = [row["centroide_lon"], row["centroide_lat"]]
    distancia = calcular_distancia_km(origem, hospital_coords, API_KEY)
    distancias_km.append(distancia)
    time.sleep(1)  # evita limite da API gratuita

grid["distancia_km"] = distancias_km
grid.to_csv(f"estimativa_guaianases.csv", index=False)

# %%
grid
# Out:
#     bbox_west  bbox_south  bbox_east  bbox_north  place_id  osm_type   osm_id  \
# 0  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 1  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 2  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 3  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 4  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 5  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 6  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 7  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 8  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 9  -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 10 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 11 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 12 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 13 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 14 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 15 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 16 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 17 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 18 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 19 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 20 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 21 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 22 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 23 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 24 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 25 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 26 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 27 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 28 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 29 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 30 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 31 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 32 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 33 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 34 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 35 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 36 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 37 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 38 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 39 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 40 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 41 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 42 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
# 43 -46.427026  -23.571868 -46.379521  -23.539495   8036116  relation  3049443
#
#           lat        lon     class  ... place_rank  importance  addresstype  \
# 0  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 1  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 2  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 3  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 4  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 5  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 6  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 7  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 8  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 9  -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 10 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 11 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 12 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 13 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 14 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 15 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 16 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 17 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 18 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 19 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 20 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 21 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 22 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 23 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 24 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 25 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 26 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 27 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 28 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 29 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 30 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 31 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 32 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 33 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 34 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 35 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 36 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 37 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 38 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 39 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 40 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 41 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 42 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
# 43 -23.544005 -46.411515  boundary  ...         18    0.389701       suburb
#
#           name                                       display_name  \
# 0   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 1   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 2   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 3   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 4   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 5   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 6   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 7   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 8   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 9   Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 10  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 11  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 12  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 13  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 14  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 15  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 16  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 17  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 18  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 19  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 20  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 21  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 22  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 23  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 24  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 25  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 26  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 27  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 28  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 29  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 30  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 31  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 32  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 33  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 34  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 35  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 36  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 37  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 38  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 39  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 40  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 41  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 42  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
# 43  Guaianases  Guaianases, São Paulo, Região Imediata de São ...
#
#                                              geometry  \
# 0   POLYGON ((-5167676.296 -2700109.977, -5167676....
# 1   POLYGON ((-5167676.296 -2699502.766, -5167676....
# 2   POLYGON ((-5167676.296 -2698895.579, -5167676....
# 3   POLYGON ((-5167676.296 -2698288.414, -5167676....
# 4   POLYGON ((-5167676.296 -2697681.273, -5167676....
# 5   POLYGON ((-5167676.296 -2697681.273, -5167953....
# 6   POLYGON ((-5167676.296 -2700109.977, -5167119....
# 7   POLYGON ((-5167676.296 -2700109.977, -5167676....
# 8   POLYGON ((-5167676.296 -2699502.766, -5167676....
# 9   POLYGON ((-5167676.296 -2698895.579, -5167676....
# 10  POLYGON ((-5167119.698 -2698288.414, -5167676....
# 11  POLYGON ((-5167676.296 -2697681.273, -5167676....
# 12  POLYGON ((-5167119.698 -2700109.977, -5166563....
# 13  POLYGON ((-5167119.698 -2700109.977, -5167119....
# 14  POLYGON ((-5167119.698 -2699502.766, -5167119....
# 15  POLYGON ((-5167119.698 -2698895.579, -5167119....
# 16  POLYGON ((-5166563.101 -2698288.414, -5167119....
# 17  POLYGON ((-5166563.101 -2700109.977, -5166006....
# 18  POLYGON ((-5166563.101 -2700109.977, -5166563....
# 19  POLYGON ((-5166563.101 -2699502.766, -5166563....
# 20  POLYGON ((-5166563.101 -2698895.579, -5166563....
# 21  POLYGON ((-5166006.504 -2698288.414, -5166563....
# 22  POLYGON ((-5166006.504 -2700109.977, -5165449....
# 23  POLYGON ((-5166006.504 -2700109.977, -5166006....
# 24  POLYGON ((-5166006.504 -2699502.766, -5166006....
# 25  POLYGON ((-5166006.504 -2698895.579, -5166006....
# 26  POLYGON ((-5165449.906 -2698288.414, -5166006....
# 27  POLYGON ((-5164893.309 -2700717.211, -5164893....
# 28  POLYGON ((-5165449.906 -2700109.977, -5164893....
# 29  POLYGON ((-5165449.906 -2700109.977, -5165449....
# 30  POLYGON ((-5165449.906 -2699502.766, -5165449....
# 31  POLYGON ((-5164893.309 -2698895.579, -5165449....
# 32  POLYGON ((-5165449.906 -2698288.414, -5165449....
# 33  POLYGON ((-5164893.309 -2700717.211, -5164336....
# 34  POLYGON ((-5164893.309 -2700717.211, -5164893....
# 35  POLYGON ((-5164336.711 -2700109.977, -5164893....
# 36  POLYGON ((-5164893.309 -2699502.766, -5164893....
# 37  POLYGON ((-5164893.309 -2698895.579, -5164893....
# 38  POLYGON ((-5164336.711 -2700717.211, -5163780....
# 39  POLYGON ((-5163780.114 -2700717.211, -5164336....
# 40  POLYGON ((-5164336.711 -2700109.977, -5164336....
# 41  POLYGON ((-5163780.114 -2700717.211, -5163279....
# 42  POLYGON ((-5163223.516 -2700589.919, -5163223....
#
#     distancia_km
# 0           2.99
# 1           3.10
# 2           3.38
# 3           3.54
# 4           2.57
# 5           2.87
# 6           2.45
# 7           1.96
# 8           1.95
# 9           2.26
# 10          2.22
# 11          2.89
# 12          2.23
# 13          1.79
# 14          1.20
# 15          1.90
# 16          1.63
# 17          1.78
# 18          1.53
# 19          0.50
# 20          0.94
# 21          0.83
# 22          2.01
# 23          1.61
# 24          0.36
# 25          0.62
# 26          1.31
# 27          2.51
# 28          1.98
# 29          1.27
# 30          1.27
# 31          1.32
# 32          1.62
# 33          3.02
# 34          2.52
# 35          1.92
# 36          1.63
# 37          1.64
# 38          5.22
# 39          2.98
# 40          2.41
# 41          5.71
# 42          3.59
# 43          3.87
#
# [44 rows x 21 columns]

# %%
# %pip install folium
import folium
from shapely.geometry import mapping

# Converter o bairro para EPSG:4326 (lat/lon) para exibição no mapa
bairro_wgs84 = bairro.to_crs(epsg=4326)
grid_wgs84 = grid.to_crs(epsg=4326)

# Criar mapa centralizado no bairro
centroide_bairro = bairro_wgs84.geometry.centroid.iloc[0]
m = folium.Map(location=[centroide_bairro.y, centroide_bairro.x], zoom_start=14)

# Adicionar polígono do bairro
folium.GeoJson(bairro_wgs84.geometry.__geo_interface__,
               name="Bairro - Tatuape",
               style_function=lambda x: {"color": "black", "fillOpacity": 0.1}
).add_to(m)

# Adicionar os grids
for _, row in grid_wgs84.iterrows():
    folium.GeoJson(mapping(row.geometry),
                   style_function=lambda x: {"color": "blue", "weight": 1, "fillOpacity": 0}
    ).add_to(m)

# Adicionar ponto do hospital
, 
folium.Marker(
    location=[-23.5521168, -46.4064284] ,
    popup="Hospital Itaquera",
    icon=folium.Icon(color='red', icon='plus-sign')
).add_to(m)

# Mostrar mapa
m

# [-46.5315852, -23.5605378]
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: folium in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (0.19.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from folium) (1.26.1)
# Requirement already satisfied: requests in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joth1\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2023.11.17)
# C:\Users\joth1\AppData\Local\Temp\ipykernel_22676\2851109843.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroide_bairro = bairro_wgs84.geometry.centroid.iloc[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e74a4185d9044a3e2af389b420ececa4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e74a4185d9044a3e2af389b420ececa4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e74a4185d9044a3e2af389b420ececa4 = L.map(
#                 &quot;map_e74a4185d9044a3e2af389b420ececa4&quot;,
#                 {
#                     center: [-23.556389304066062, -46.406749066785814],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07a64280937f68650878f666f17a88a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07a64280937f68650878f666f17a88a8.addTo(map_e74a4185d9044a3e2af389b420ececa4);
#
#
#         function geo_json_1239f4bd23c75049aa5481ce16addd2e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.1};
#             }
#         }
#
#         function geo_json_1239f4bd23c75049aa5481ce16addd2e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1239f4bd23c75049aa5481ce16addd2e = L.geoJson(null, {
#                 onEachFeature: geo_json_1239f4bd23c75049aa5481ce16addd2e_onEachFeature,
#
#                 style: geo_json_1239f4bd23c75049aa5481ce16addd2e_styler,
#             ...{
# }
#         });
#
#         function geo_json_1239f4bd23c75049aa5481ce16addd2e_add (data) {
#             geo_json_1239f4bd23c75049aa5481ce16addd2e
#                 .addData(data);
#         }
#             geo_json_1239f4bd23c75049aa5481ce16addd2e_add({&quot;bbox&quot;: [-46.427026, -23.571868, -46.3795209, -23.5394948], &quot;features&quot;: [{&quot;bbox&quot;: [-46.427026, -23.571868, -46.3795209, -23.5394948], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[